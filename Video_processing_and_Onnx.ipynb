# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Video Processing

# %%
import cv2
import torch
from torchvision.transforms import functional as F
from PIL import Image
import math
import numpy as np

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
model = torch.load('/content/drive/MyDrive/drone_detection_ssd_model.pth', map_location=torch.device('cpu'))
model.eval().to(device)

def frame_to_tensor(frame):
    img = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    img = F.to_tensor(img).to(device)
    return img

def draw_bounding_boxes(frame, boxes, labels):
    for box in boxes:
        x_min, y_min, x_max, y_max = map(int, box)
        cv2.rectangle(frame, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
    return frame

def process_video(input_path, output_path):
    cap = cv2.VideoCapture(input_path)
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    codec = cv2.VideoWriter_fourcc(*'mp4v')
    out = cv2.VideoWriter(output_path, codec, fps, (width, height))
    print(f"FPS: {fps}")

    idx = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        img_tensor = frame_to_tensor(frame).unsqueeze(0)
        with torch.no_grad():
            outputs = model(img_tensor)

        predicted_box = torch.argmax(outputs[0]['scores'])
        labels = outputs[0]['labels'][predicted_box].cpu().numpy()
        boxes = outputs[0]['boxes'][predicted_box].unsqueeze(0).cpu().numpy()

        x_min, y_min, x_max, y_max = boxes[0]

        center_box = ((x_min + x_max) / 2, (y_min + y_max) / 2)
        delta_x = center_box[0] - width / 2
        delta_y = center_box[1] - height / 2
        angle_rad = math.atan2(delta_y, delta_x)
        angle_deg = math.degrees(angle_rad)
        angle_deg_from_y = (angle_deg + 90) % 360
        if angle_deg_from_y < 0:
          angle_deg_from_y += 360
        print(f"{idx} Angle in degrees from positive y-axis: {angle_deg_from_y}")
        idx += 1

        start_point = (int(width / 2), int(height / 2))
        end_point = (int(center_box[0]), int(center_box[1]))
        color = (255, 0, 0)
        thickness = 2
        image = cv2.line(frame, start_point, end_point, color, thickness)

        frame = draw_bounding_boxes(frame, boxes, labels)
        out.write(frame)

    cap.release()
    out.release()
    print("Processed video saved at:", output_path)

# %%
input_video_path = '/content/drive/MyDrive/drone_short_vid.mp4'
output_video_path = '/content/drive/MyDrive/output_video_with_bboxes.mp4'
process_video(input_video_path, output_video_path)
# Out:
# FPS: 25
# 0 Angle in degrees from positive y-axis: 183.69313528185134
# 1 Angle in degrees from positive y-axis: 184.53700753322846
# 2 Angle in degrees from positive y-axis: 184.451082764353
# 3 Angle in degrees from positive y-axis: 185.3526793025631
# 4 Angle in degrees from positive y-axis: 185.13229771252978
# 5 Angle in degrees from positive y-axis: 185.08717887358662
# 6 Angle in degrees from positive y-axis: 184.7797504611056
# 7 Angle in degrees from positive y-axis: 182.42081733639367
# 8 Angle in degrees from positive y-axis: 188.70748370369364
# 9 Angle in degrees from positive y-axis: 182.9279575837651
# 10 Angle in degrees from positive y-axis: 184.05687861380352
# 11 Angle in degrees from positive y-axis: 183.954786159454
# 12 Angle in degrees from positive y-axis: 183.35049347828
# 13 Angle in degrees from positive y-axis: 180.95419442178667
# 14 Angle in degrees from positive y-axis: 175.95700946890514
# 15 Angle in degrees from positive y-axis: 175.70029126987544
# 16 Angle in degrees from positive y-axis: 176.22280375404932
# 17 Angle in degrees from positive y-axis: 175.99631946091492
# 18 Angle in degrees from positive y-axis: 174.78027028790808
# 19 Angle in degrees from positive y-axis: 175.24195813283367
# 20 Angle in degrees from positive y-axis: 175.24774355267965
# 21 Angle in degrees from positive y-axis: 175.47200533299036
# 22 Angle in degrees from positive y-axis: 174.34917383287402
# 23 Angle in degrees from positive y-axis: 176.78525328985666
# 24 Angle in degrees from positive y-axis: 175.67559550141942
# 25 Angle in degrees from positive y-axis: 175.20005970872413
# 26 Angle in degrees from positive y-axis: 176.1790063725971
# 27 Angle in degrees from positive y-axis: 180.62019888160927
# 28 Angle in degrees from positive y-axis: 182.94079659844056
# 29 Angle in degrees from positive y-axis: 182.8120836295937
# 30 Angle in degrees from positive y-axis: 183.31989376006274
# 31 Angle in degrees from positive y-axis: 183.37909266688277
# 32 Angle in degrees from positive y-axis: 184.1026911113072
# 33 Angle in degrees from positive y-axis: 183.37658219674574
# 34 Angle in degrees from positive y-axis: 182.27393704598234
# 35 Angle in degrees from positive y-axis: 179.8707644656467
# 36 Angle in degrees from positive y-axis: 181.70672739978866
# 37 Angle in degrees from positive y-axis: 180.177289765409
# 38 Angle in degrees from positive y-axis: 184.32225431259383
# 39 Angle in degrees from positive y-axis: 186.17915168535956
# 40 Angle in degrees from positive y-axis: 180.99865070788093
# 41 Angle in degrees from positive y-axis: 179.08385226192266
# 42 Angle in degrees from positive y-axis: 179.69625318406153
# 43 Angle in degrees from positive y-axis: 178.76930840938724
# 44 Angle in degrees from positive y-axis: 182.1533790199394
# 45 Angle in degrees from positive y-axis: 184.19146770262293
# 46 Angle in degrees from positive y-axis: 184.74909616903903
# 47 Angle in degrees from positive y-axis: 184.3364768517058
# 48 Angle in degrees from positive y-axis: 190.61965891532327
# 49 Angle in degrees from positive y-axis: 188.73799359276305
# 50 Angle in degrees from positive y-axis: 181.25558444375832
# 51 Angle in degrees from positive y-axis: 188.46296972344624
# 52 Angle in degrees from positive y-axis: 178.14760558599224
# 53 Angle in degrees from positive y-axis: 177.1021549051682
# 54 Angle in degrees from positive y-axis: 183.2910100069646
# 55 Angle in degrees from positive y-axis: 185.64217588845827
# 56 Angle in degrees from positive y-axis: 185.18789454333245
# 57 Angle in degrees from positive y-axis: 186.04652506626883
# 58 Angle in degrees from positive y-axis: 183.12756177318929
# 59 Angle in degrees from positive y-axis: 183.07951055540434
# 60 Angle in degrees from positive y-axis: 176.3597967259024
# 61 Angle in degrees from positive y-axis: 183.2057804443973
# 62 Angle in degrees from positive y-axis: 184.90692362649423
# 63 Angle in degrees from positive y-axis: 188.5979653911255
# 64 Angle in degrees from positive y-axis: 186.6085553893924
# 65 Angle in degrees from positive y-axis: 182.83291516617044
# 66 Angle in degrees from positive y-axis: 182.59198582070155
# 67 Angle in degrees from positive y-axis: 182.9273540011797
# 68 Angle in degrees from positive y-axis: 177.3884620282923
# 69 Angle in degrees from positive y-axis: 183.38677196197742
# 70 Angle in degrees from positive y-axis: 184.3222540594993
# 71 Angle in degrees from positive y-axis: 182.1372496187464
# 72 Angle in degrees from positive y-axis: 184.0165002381012
# 73 Angle in degrees from positive y-axis: 183.68544098713767
# 74 Angle in degrees from positive y-axis: 185.56992768913403
# 75 Angle in degrees from positive y-axis: 187.14164554138767
# 76 Angle in degrees from positive y-axis: 183.9598872150217
# 77 Angle in degrees from positive y-axis: 186.1381647344282
# 78 Angle in degrees from positive y-axis: 184.5146032635704
# 79 Angle in degrees from positive y-axis: 186.52654223665894
# 80 Angle in degrees from positive y-axis: 185.80497806425717
# 81 Angle in degrees from positive y-axis: 184.38896623314844
# 82 Angle in degrees from positive y-axis: 185.29187857384727
# 83 Angle in degrees from positive y-axis: 184.57206927816185
# 84 Angle in degrees from positive y-axis: 185.89968920694253
# 85 Angle in degrees from positive y-axis: 186.20025413666497
# 86 Angle in degrees from positive y-axis: 186.30741352714344
# 87 Angle in degrees from positive y-axis: 185.59094401050945
# 88 Angle in degrees from positive y-axis: 184.75649569704646
# 89 Angle in degrees from positive y-axis: 185.65790205764205
# 90 Angle in degrees from positive y-axis: 185.34361659773498
# 91 Angle in degrees from positive y-axis: 185.76674248839169
# 92 Angle in degrees from positive y-axis: 186.9808325467111
# 93 Angle in degrees from positive y-axis: 186.34050474699657
# 94 Angle in degrees from positive y-axis: 184.9435094625527
# 95 Angle in degrees from positive y-axis: 185.7498180560537
# 96 Angle in degrees from positive y-axis: 185.8652666836615
# 97 Angle in degrees from positive y-axis: 184.594598946157
# 98 Angle in degrees from positive y-axis: 187.4352788169707
# 99 Angle in degrees from positive y-axis: 188.4574121594182
# 100 Angle in degrees from positive y-axis: 187.08143685051095
# 101 Angle in degrees from positive y-axis: 187.62303578706852
# 102 Angle in degrees from positive y-axis: 187.23122080944617
# 103 Angle in degrees from positive y-axis: 187.99119645709155
# 104 Angle in degrees from positive y-axis: 188.30432495527347
# 105 Angle in degrees from positive y-axis: 187.85543427044541
# 106 Angle in degrees from positive y-axis: 187.7299838797053
# 107 Angle in degrees from positive y-axis: 188.4477497874757
# 108 Angle in degrees from positive y-axis: 188.71108034315242
# 109 Angle in degrees from positive y-axis: 187.97755382942194
# 110 Angle in degrees from positive y-axis: 188.96642467348298
# 111 Angle in degrees from positive y-axis: 189.52635742417743
# 112 Angle in degrees from positive y-axis: 189.00199094622255
# 113 Angle in degrees from positive y-axis: 190.40312836786887
# 114 Angle in degrees from positive y-axis: 190.1331659172377
# 115 Angle in degrees from positive y-axis: 190.20455488219105
# 116 Angle in degrees from positive y-axis: 191.3058979052651
# 117 Angle in degrees from positive y-axis: 191.4369764300145
# 118 Angle in degrees from positive y-axis: 191.1836742196679
# 119 Angle in degrees from positive y-axis: 191.9401596158925
# 120 Angle in degrees from positive y-axis: 191.56355938366886
# 121 Angle in degrees from positive y-axis: 191.82343808967727
# 122 Angle in degrees from positive y-axis: 192.0321140163382
# 123 Angle in degrees from positive y-axis: 191.79470305531214
# 124 Angle in degrees from positive y-axis: 191.8251124550703
# 125 Angle in degrees from positive y-axis: 189.79949419744412
# 126 Angle in degrees from positive y-axis: 189.9664367586671
# 127 Angle in degrees from positive y-axis: 191.18744057436254
# 128 Angle in degrees from positive y-axis: 190.0008807572213
# 129 Angle in degrees from positive y-axis: 191.48717981547307
# 130 Angle in degrees from positive y-axis: 193.1867086176278
# 131 Angle in degrees from positive y-axis: 191.8908815764176
# 132 Angle in degrees from positive y-axis: 191.93271444868552
# 133 Angle in degrees from positive y-axis: 192.0119331013231
# 134 Angle in degrees from positive y-axis: 190.49557478326773
# 135 Angle in degrees from positive y-axis: 191.2606218047758
# 136 Angle in degrees from positive y-axis: 190.70591448127465
# 137 Angle in degrees from positive y-axis: 190.87220011805357
# 138 Angle in degrees from positive y-axis: 191.201751145555
# 139 Angle in degrees from positive y-axis: 190.49520517512116
# 140 Angle in degrees from positive y-axis: 192.0523849682291
# 141 Angle in degrees from positive y-axis: 190.27017788255614
# 142 Angle in degrees from positive y-axis: 188.74929031137208
# 143 Angle in degrees from positive y-axis: 189.38889371795807
# 144 Angle in degrees from positive y-axis: 187.3916866337981
# 145 Angle in degrees from positive y-axis: 188.7806913435938
# 146 Angle in degrees from positive y-axis: 189.56288384224473
# 147 Angle in degrees from positive y-axis: 189.34695259698694
# 148 Angle in degrees from positive y-axis: 188.96416446259786
# 149 Angle in degrees from positive y-axis: 190.1097707793042
# 150 Angle in degrees from positive y-axis: 190.22438665322986
# 151 Angle in degrees from positive y-axis: 190.01492468688048
# 152 Angle in degrees from positive y-axis: 189.8102688966111
# 153 Angle in degrees from positive y-axis: 189.09783041376843
# 154 Angle in degrees from positive y-axis: 188.1779217714464
# 155 Angle in degrees from positive y-axis: 186.4824679687161
# 156 Angle in degrees from positive y-axis: 188.46370611994251
# 157 Angle in degrees from positive y-axis: 188.14184034980417
# 158 Angle in degrees from positive y-axis: 188.74169420670307
# 159 Angle in degrees from positive y-axis: 187.78757607865802
# 160 Angle in degrees from positive y-axis: 188.54126377707115
# 161 Angle in degrees from positive y-axis: 187.27197553941022
# 162 Angle in degrees from positive y-axis: 188.41028460238684
# 163 Angle in degrees from positive y-axis: 188.70456246213047
# 164 Angle in degrees from positive y-axis: 189.48842609240617
# 165 Angle in degrees from positive y-axis: 187.80886952086595
# 166 Angle in degrees from positive y-axis: 188.32702247755634
# 167 Angle in degrees from positive y-axis: 188.15440926785953
# 168 Angle in degrees from positive y-axis: 186.7902916805909
# 169 Angle in degrees from positive y-axis: 186.5546592665386
# 170 Angle in degrees from positive y-axis: 186.31559614591484
# 171 Angle in degrees from positive y-axis: 185.9839977036238
# 172 Angle in degrees from positive y-axis: 187.2454311149989
# 173 Angle in degrees from positive y-axis: 187.6679615146497
# 174 Angle in degrees from positive y-axis: 188.0536106653455
# 175 Angle in degrees from positive y-axis: 186.44308496376811
# 176 Angle in degrees from positive y-axis: 185.29623749992513
# 177 Angle in degrees from positive y-axis: 194.5954780155197
# 178 Angle in degrees from positive y-axis: 184.72548763955916
# 179 Angle in degrees from positive y-axis: 184.32089494792896
# 180 Angle in degrees from positive y-axis: 184.28610130881725
# 181 Angle in degrees from positive y-axis: 176.43847772719872
# 182 Angle in degrees from positive y-axis: 212.42590472616826
# 183 Angle in degrees from positive y-axis: 214.52229667003422
# 184 Angle in degrees from positive y-axis: 210.41958766259745
# 185 Angle in degrees from positive y-axis: 185.09385849869568
# 186 Angle in degrees from positive y-axis: 190.6039323007186
# 187 Angle in degrees from positive y-axis: 189.74556643591245
# 188 Angle in degrees from positive y-axis: 204.13970780684713
# 189 Angle in degrees from positive y-axis: 316.80107062146817
# 190 Angle in degrees from positive y-axis: 319.97086064992124
# 191 Angle in degrees from positive y-axis: 316.66529787676245
# 192 Angle in degrees from positive y-axis: 321.99111242093
# 193 Angle in degrees from positive y-axis: 324.8034154172802
# 194 Angle in degrees from positive y-axis: 325.3166004252346
# 195 Angle in degrees from positive y-axis: 64.32134712024103
# 196 Angle in degrees from positive y-axis: 65.24599439036194
# 197 Angle in degrees from positive y-axis: 70.89992155540736
# 198 Angle in degrees from positive y-axis: 71.64065181585252
# 199 Angle in degrees from positive y-axis: 68.08296998755861
# 200 Angle in degrees from positive y-axis: 65.9680932995658
# 201 Angle in degrees from positive y-axis: 66.22181554382976
# 202 Angle in degrees from positive y-axis: 73.12511768086526
# 203 Angle in degrees from positive y-axis: 59.79487900694525
# 204 Angle in degrees from positive y-axis: 58.05662077416866
# 205 Angle in degrees from positive y-axis: 56.2223388831437
# 206 Angle in degrees from positive y-axis: 57.259976240873726
# 207 Angle in degrees from positive y-axis: 55.57595030587184
# 208 Angle in degrees from positive y-axis: 54.846908341649225
# 209 Angle in degrees from positive y-axis: 51.37323641343623
# 210 Angle in degrees from positive y-axis: 7.915126306544977
# 211 Angle in degrees from positive y-axis: 56.4288075480516
# 212 Angle in degrees from positive y-axis: 56.6170823667112
# 213 Angle in degrees from positive y-axis: 56.86986618957472
# 214 Angle in degrees from positive y-axis: 57.55267388838347
# 215 Angle in degrees from positive y-axis: 58.113944193063574
# 216 Angle in degrees from positive y-axis: 60.16451482443104
# 217 Angle in degrees from positive y-axis: 61.78201092345374
# 218 Angle in degrees from positive y-axis: 60.11790725734763
# 219 Angle in degrees from positive y-axis: 60.977241055223516
# 220 Angle in degrees from positive y-axis: 70.3307025823882
# 221 Angle in degrees from positive y-axis: 70.43089755593121
# 222 Angle in degrees from positive y-axis: 74.13793886696266
# 223 Angle in degrees from positive y-axis: 80.46468622248915
# 224 Angle in degrees from positive y-axis: 75.79600156253703
# 225 Angle in degrees from positive y-axis: 77.65265646271406
# 226 Angle in degrees from positive y-axis: 78.37816327586387
# 227 Angle in degrees from positive y-axis: 78.72406959902314
# 228 Angle in degrees from positive y-axis: 84.05555594068532
# 229 Angle in degrees from positive y-axis: 87.89152156542316
# 230 Angle in degrees from positive y-axis: 96.90432926536853
# 231 Angle in degrees from positive y-axis: 93.83478140272109
# 232 Angle in degrees from positive y-axis: 94.26649734387593
# 233 Angle in degrees from positive y-axis: 97.26276872609964
# 234 Angle in degrees from positive y-axis: 98.63501809286606
# 235 Angle in degrees from positive y-axis: 99.71295164745743
# 236 Angle in degrees from positive y-axis: 99.67373794136006
# 237 Angle in degrees from positive y-axis: 101.18950003862199
# 238 Angle in degrees from positive y-axis: 100.13651786676594
# 239 Angle in degrees from positive y-axis: 99.37501456838231
# 240 Angle in degrees from positive y-axis: 93.61724429642645
# 241 Angle in degrees from positive y-axis: 92.57538810008333
# 242 Angle in degrees from positive y-axis: 83.20381206499381
# 243 Angle in degrees from positive y-axis: 79.95039836649798
# 244 Angle in degrees from positive y-axis: 76.38780397796806
# 245 Angle in degrees from positive y-axis: 67.42765658866487
# 246 Angle in degrees from positive y-axis: 67.97791533187106
# 247 Angle in degrees from positive y-axis: 63.272335866610064
# 248 Angle in degrees from positive y-axis: 63.515563694178404
# 249 Angle in degrees from positive y-axis: 62.105344753595226
# 250 Angle in degrees from positive y-axis: 61.49519393006616
# 251 Angle in degrees from positive y-axis: 84.058170722947
# 252 Angle in degrees from positive y-axis: 80.11828588720905
# 253 Angle in degrees from positive y-axis: 77.12753467798142
# 254 Angle in degrees from positive y-axis: 62.76841500685082
# 255 Angle in degrees from positive y-axis: 59.820547343195855
# 256 Angle in degrees from positive y-axis: 58.14027626517271
# 257 Angle in degrees from positive y-axis: 271.1133411119748
# 258 Angle in degrees from positive y-axis: 57.503757784978404
# 259 Angle in degrees from positive y-axis: 56.9703535129592
# 260 Angle in degrees from positive y-axis: 58.9025316252619
# 261 Angle in degrees from positive y-axis: 57.88420050662745
# 262 Angle in degrees from positive y-axis: 54.66304890557473
# 263 Angle in degrees from positive y-axis: 54.97691399627948
# 264 Angle in degrees from positive y-axis: 56.02195531541066
# 265 Angle in degrees from positive y-axis: 57.28894873223885
# 266 Angle in degrees from positive y-axis: 56.5154598175561
# 267 Angle in degrees from positive y-axis: 58.15990349823505
# 268 Angle in degrees from positive y-axis: 56.509405403624
# 269 Angle in degrees from positive y-axis: 55.757303813995364
# 270 Angle in degrees from positive y-axis: 55.946367738652086
# 271 Angle in degrees from positive y-axis: 57.07251827265146
# 272 Angle in degrees from positive y-axis: 56.578828944405096
# 273 Angle in degrees from positive y-axis: 58.6484198004223
# 274 Angle in degrees from positive y-axis: 57.195320002409
# 275 Angle in degrees from positive y-axis: 57.642792006628504
# 276 Angle in degrees from positive y-axis: 55.771468795539796
# 277 Angle in degrees from positive y-axis: 56.44393737347107
# 278 Angle in degrees from positive y-axis: 56.39838235486186
# 279 Angle in degrees from positive y-axis: 55.25196783287444
# 280 Angle in degrees from positive y-axis: 333.37819762893974
# 281 Angle in degrees from positive y-axis: 330.59391767457464
# 282 Angle in degrees from positive y-axis: 52.21505556153474
# 283 Angle in degrees from positive y-axis: 54.250304471167375
# 284 Angle in degrees from positive y-axis: 55.207718081690565
# 285 Angle in degrees from positive y-axis: 57.60760116852607
# 286 Angle in degrees from positive y-axis: 57.67030281522493
# 287 Angle in degrees from positive y-axis: 52.0728825308738
# 288 Angle in degrees from positive y-axis: 58.68685258433243
# 289 Angle in degrees from positive y-axis: 325.5984179919285
# 290 Angle in degrees from positive y-axis: 60.27322160917406
# 291 Angle in degrees from positive y-axis: 58.53505624538651
# 292 Angle in degrees from positive y-axis: 324.05996718682024
# 293 Angle in degrees from positive y-axis: 333.8600971294891
# 294 Angle in degrees from positive y-axis: 335.87278652261466
# 295 Angle in degrees from positive y-axis: 336.99557335226325
# 296 Angle in degrees from positive y-axis: 344.2390894369811
# 297 Angle in degrees from positive y-axis: 347.8516373157638
# 298 Angle in degrees from positive y-axis: 348.8114602526305
# 299 Angle in degrees from positive y-axis: 351.42124044986946
# 300 Angle in degrees from positive y-axis: 349.1159517538043
# 301 Angle in degrees from positive y-axis: 348.82533810739614
# 302 Angle in degrees from positive y-axis: 348.84145712517966
# 303 Angle in degrees from positive y-axis: 348.9811099471266
# 304 Angle in degrees from positive y-axis: 356.7335807029279
# 305 Angle in degrees from positive y-axis: 350.61962516578456
# 306 Angle in degrees from positive y-axis: 353.2388130031536
# 307 Angle in degrees from positive y-axis: 358.14656842984675
# 308 Angle in degrees from positive y-axis: 357.07383940538386
# 309 Angle in degrees from positive y-axis: 351.84966070130156
# 310 Angle in degrees from positive y-axis: 348.04141268569543
# 311 Angle in degrees from positive y-axis: 349.2281163963823
# 312 Angle in degrees from positive y-axis: 346.5579604073301
# 313 Angle in degrees from positive y-axis: 344.5490712102153
# 314 Angle in degrees from positive y-axis: 342.45966897853197
# 315 Angle in degrees from positive y-axis: 344.18296302150816
# 316 Angle in degrees from positive y-axis: 336.7302778963224
# 317 Angle in degrees from positive y-axis: 339.70226596155936
# 318 Angle in degrees from positive y-axis: 334.59513673784886
# 319 Angle in degrees from positive y-axis: 336.57911720800365
# 320 Angle in degrees from positive y-axis: 339.9895651147109
# 321 Angle in degrees from positive y-axis: 337.55729866784714
# 322 Angle in degrees from positive y-axis: 336.1241912305816
# 323 Angle in degrees from positive y-axis: 333.4685495854791
# 324 Angle in degrees from positive y-axis: 336.0971846897212
# 325 Angle in degrees from positive y-axis: 334.9257943861265
# 326 Angle in degrees from positive y-axis: 335.3900848167013
# 327 Angle in degrees from positive y-axis: 335.86902969573765
# 328 Angle in degrees from positive y-axis: 333.0788101604556
# 329 Angle in degrees from positive y-axis: 333.79631961534267
# 330 Angle in degrees from positive y-axis: 333.5409138004329
# 331 Angle in degrees from positive y-axis: 331.83576165192443
# 332 Angle in degrees from positive y-axis: 332.1248695558435
# 333 Angle in degrees from positive y-axis: 329.1692900445335
# 334 Angle in degrees from positive y-axis: 329.137583468566
# 335 Angle in degrees from positive y-axis: 329.98851329069737
# 336 Angle in degrees from positive y-axis: 328.8255128136567
# 337 Angle in degrees from positive y-axis: 324.2332338650409
# 338 Angle in degrees from positive y-axis: 323.61146691993537
# 339 Angle in degrees from positive y-axis: 324.5540877131497
# 340 Angle in degrees from positive y-axis: 322.65302539143994
# 341 Angle in degrees from positive y-axis: 323.4436968857704
# 342 Angle in degrees from positive y-axis: 322.8737785908215
# 343 Angle in degrees from positive y-axis: 324.7927962834579
# 344 Angle in degrees from positive y-axis: 325.6281212951252
# 345 Angle in degrees from positive y-axis: 327.0333631740838
# 346 Angle in degrees from positive y-axis: 325.03169204080405
# 347 Angle in degrees from positive y-axis: 324.17568030123954
# 348 Angle in degrees from positive y-axis: 324.26121639651166
# 349 Angle in degrees from positive y-axis: 325.4718616529527
# 350 Angle in degrees from positive y-axis: 326.6995350726743
# 351 Angle in degrees from positive y-axis: 329.9691119188288
# 352 Angle in degrees from positive y-axis: 329.0176565692208
# 353 Angle in degrees from positive y-axis: 330.886291881127
# 354 Angle in degrees from positive y-axis: 333.48806133209246
# 355 Angle in degrees from positive y-axis: 335.4196230022054
# 356 Angle in degrees from positive y-axis: 336.78402603852487
# 357 Angle in degrees from positive y-axis: 337.57801633091697
# 358 Angle in degrees from positive y-axis: 337.9447880137767
# 359 Angle in degrees from positive y-axis: 338.7517159033136
# 360 Angle in degrees from positive y-axis: 337.12890262532227
# 361 Angle in degrees from positive y-axis: 336.88516200839706
# 362 Angle in degrees from positive y-axis: 335.75995844698
# 363 Angle in degrees from positive y-axis: 335.8578820735788
# 364 Angle in degrees from positive y-axis: 336.25444872845304
# 365 Angle in degrees from positive y-axis: 337.6684001455872
# 366 Angle in degrees from positive y-axis: 337.64586797805686
# 367 Angle in degrees from positive y-axis: 336.93795453957915
# 368 Angle in degrees from positive y-axis: 338.2783613751358
# 369 Angle in degrees from positive y-axis: 334.9460062522394
# 370 Angle in degrees from positive y-axis: 337.7881881043944
# 371 Angle in degrees from positive y-axis: 341.9346730078964
# 372 Angle in degrees from positive y-axis: 341.4877297812849
# 373 Angle in degrees from positive y-axis: 344.6501041346329
# 374 Angle in degrees from positive y-axis: 350.63196822488607
# 375 Angle in degrees from positive y-axis: 356.14376476412804
# 376 Angle in degrees from positive y-axis: 357.52085641991954
# 377 Angle in degrees from positive y-axis: 349.50949636403334
# 378 Angle in degrees from positive y-axis: 131.91472797355752
# 379 Angle in degrees from positive y-axis: 14.655111290942898
# 380 Angle in degrees from positive y-axis: 16.50314919452913
# 381 Angle in degrees from positive y-axis: 23.40183215148727
# 382 Angle in degrees from positive y-axis: 24.57818345345642
# 383 Angle in degrees from positive y-axis: 25.75605072724416
# 384 Angle in degrees from positive y-axis: 25.167940868395746
# 385 Angle in degrees from positive y-axis: 29.36260966982818
# 386 Angle in degrees from positive y-axis: 34.20555827719721
# 387 Angle in degrees from positive y-axis: 39.27272481909872
# 388 Angle in degrees from positive y-axis: 36.79250527813588
# 389 Angle in degrees from positive y-axis: 38.57499206406761
# 390 Angle in degrees from positive y-axis: 39.04134799987563
# 391 Angle in degrees from positive y-axis: 45.036225095314535
# 392 Angle in degrees from positive y-axis: 336.1790479042851
# 393 Angle in degrees from positive y-axis: 337.19279486725304
# 394 Angle in degrees from positive y-axis: 337.1192804125599
# 395 Angle in degrees from positive y-axis: 17.160093156092643
# 396 Angle in degrees from positive y-axis: 20.746407263237458
# 397 Angle in degrees from positive y-axis: 19.75079551732665
# 398 Angle in degrees from positive y-axis: 40.99466807535654
# 399 Angle in degrees from positive y-axis: 68.37978026828526
# 400 Angle in degrees from positive y-axis: 16.834691287116343
# 401 Angle in degrees from positive y-axis: 37.76207936139484
# 402 Angle in degrees from positive y-axis: 68.0887211543278
# 403 Angle in degrees from positive y-axis: 67.40473544676453
# 404 Angle in degrees from positive y-axis: 65.7913066959471
# 405 Angle in degrees from positive y-axis: 14.285323191538339
# 406 Angle in degrees from positive y-axis: 17.085787733250186
# 407 Angle in degrees from positive y-axis: 331.00737049668123
# 408 Angle in degrees from positive y-axis: 333.93170874759994
# 409 Angle in degrees from positive y-axis: 335.73908240634955
# 410 Angle in degrees from positive y-axis: 330.76986697342994
# 411 Angle in degrees from positive y-axis: 326.52459236521287
# 412 Angle in degrees from positive y-axis: 321.60322962528414
# 413 Angle in degrees from positive y-axis: 39.31216777370507
# 414 Angle in degrees from positive y-axis: 321.11328731550077
# 415 Angle in degrees from positive y-axis: 35.00489183658397
# 416 Angle in degrees from positive y-axis: 329.3665684088602
# 417 Angle in degrees from positive y-axis: 326.9732898649904
# 418 Angle in degrees from positive y-axis: 323.4402436282697
# 419 Angle in degrees from positive y-axis: 131.90205416040777
# 420 Angle in degrees from positive y-axis: 34.309961904365075
# 421 Angle in degrees from positive y-axis: 36.30368028356233
# 422 Angle in degrees from positive y-axis: 327.9444594336609
# 423 Angle in degrees from positive y-axis: 325.1634214769961
# 424 Angle in degrees from positive y-axis: 325.37760954188565
# 425 Angle in degrees from positive y-axis: 36.99954806818505
# 426 Angle in degrees from positive y-axis: 39.75572730372602
# 427 Angle in degrees from positive y-axis: 43.473544571196044
# 428 Angle in degrees from positive y-axis: 45.35919915360115
# 429 Angle in degrees from positive y-axis: 43.3071528775404
# 430 Angle in degrees from positive y-axis: 132.42693734454838
# 431 Angle in degrees from positive y-axis: 130.32785579501197
# 432 Angle in degrees from positive y-axis: 38.62478443260333
# 433 Angle in degrees from positive y-axis: 41.90774514392312
# 434 Angle in degrees from positive y-axis: 43.674693457060144
# 435 Angle in degrees from positive y-axis: 133.2208994764227
# 436 Angle in degrees from positive y-axis: 130.61416377657588
# 437 Angle in degrees from positive y-axis: 130.8486543091133
# 438 Angle in degrees from positive y-axis: 128.52536789402845
# 439 Angle in degrees from positive y-axis: 131.8212656550645
# 440 Angle in degrees from positive y-axis: 31.948470632964764
# 441 Angle in degrees from positive y-axis: 28.853030579144324
# 442 Angle in degrees from positive y-axis: 25.4712095443398
# 443 Angle in degrees from positive y-axis: 132.43302330072862
# 444 Angle in degrees from positive y-axis: 130.04656793150795
# 445 Angle in degrees from positive y-axis: 18.4793748995978
# 446 Angle in degrees from positive y-axis: 25.424567609530058
# 447 Angle in degrees from positive y-axis: 130.91135606677415
# 448 Angle in degrees from positive y-axis: 131.45945656725758
# 449 Angle in degrees from positive y-axis: 130.81882322271696
# 450 Angle in degrees from positive y-axis: 131.9287515307353
# 451 Angle in degrees from positive y-axis: 132.42617140209666
# 452 Angle in degrees from positive y-axis: 129.5613633460945
# 453 Angle in degrees from positive y-axis: 132.07376916298477
# 454 Angle in degrees from positive y-axis: 133.81293199131787
# 455 Angle in degrees from positive y-axis: 131.461894034627
# 456 Angle in degrees from positive y-axis: 134.02063643861447
# 457 Angle in degrees from positive y-axis: 134.66682056375086
# 458 Angle in degrees from positive y-axis: 133.45573030622825
# 459 Angle in degrees from positive y-axis: 130.39238870231668
# 460 Angle in degrees from positive y-axis: 131.7245716818059
# 461 Angle in degrees from positive y-axis: 132.68744075525262
# 462 Angle in degrees from positive y-axis: 132.25862767593574
# 463 Angle in degrees from positive y-axis: 131.87998211063515
# 464 Angle in degrees from positive y-axis: 131.25273754024767
# 465 Angle in degrees from positive y-axis: 130.6968716432061
# 466 Angle in degrees from positive y-axis: 128.62785273896677
# 467 Angle in degrees from positive y-axis: 4.038392753566768
# 468 Angle in degrees from positive y-axis: 129.30676403473242
# 469 Angle in degrees from positive y-axis: 132.19433428074433
# 470 Angle in degrees from positive y-axis: 132.3510764726333
# 471 Angle in degrees from positive y-axis: 131.83619084725578
# 472 Angle in degrees from positive y-axis: 132.26039375324905
# 473 Angle in degrees from positive y-axis: 131.9836285910107
# 474 Angle in degrees from positive y-axis: 132.2869500713704
# 475 Angle in degrees from positive y-axis: 133.11199700516744
# 476 Angle in degrees from positive y-axis: 134.07699058094096
# 477 Angle in degrees from positive y-axis: 132.9002045268942
# 478 Angle in degrees from positive y-axis: 132.63797544621082
# 479 Angle in degrees from positive y-axis: 132.33450357837955
# 480 Angle in degrees from positive y-axis: 131.7241297836341
# 481 Angle in degrees from positive y-axis: 131.92640742355678
# 482 Angle in degrees from positive y-axis: 130.92841825157012
# 483 Angle in degrees from positive y-axis: 131.10013749137156
# 484 Angle in degrees from positive y-axis: 130.6384407796375
# 485 Angle in degrees from positive y-axis: 130.63672897700923
# 486 Angle in degrees from positive y-axis: 341.68708820851805
# 487 Angle in degrees from positive y-axis: 342.8480517392751
# 488 Angle in degrees from positive y-axis: 343.13091349246
# 489 Angle in degrees from positive y-axis: 344.05265953771953
# 490 Angle in degrees from positive y-axis: 342.1730885106498
# 491 Angle in degrees from positive y-axis: 336.311068715115
# 492 Angle in degrees from positive y-axis: 346.8264921395181
# Processed video saved at: /content/drive/MyDrive/output_video_with_bboxes.mp4

# %% [markdown]
# ## Creating omnx

# %%
# !pip install onnx --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 45.8 MB/s eta 0:00:00

# %%
import torch
import torchvision.models.detection as detection
import onnx

model = torch.load('/content/drive/MyDrive/drone_detection_ssd_model.pth', map_location=torch.device('cpu'))
model.eval()

dummy_input = torch.randn(1, 3, 320, 320)

onnx_model_path = "/content/drive/MyDrive/ssdlite320_mobilenet_v3_large.onnx"
torch.onnx.export(
    model,
    dummy_input,
    onnx_model_path,
    verbose=True,
    opset_version=11,
    input_names=['input'],
    output_names=['output'],
    dynamic_axes={
        'input': {0: 'batch_size'},
        'output': {0: 'batch_size'}
    }
)

print(f"Model has been converted to ONNX and saved at {onnx_model_path}")
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/ops/boxes.py:166: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   boxes_x = torch.min(boxes_x, torch.tensor(width, dtype=boxes.dtype, device=boxes.device))
# /usr/local/lib/python3.10/dist-packages/torchvision/ops/boxes.py:168: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   boxes_y = torch.min(boxes_y, torch.tensor(height, dtype=boxes.dtype, device=boxes.device))
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/transform.py:308: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   torch.tensor(s, dtype=torch.float32, device=boxes.device)
# /usr/local/lib/python3.10/dist-packages/torchvision/models/detection/transform.py:309: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   / torch.tensor(s_orig, dtype=torch.float32, device=boxes.device)
# Model has been converted to ONNX and saved at /content/drive/MyDrive/ssdlite320_mobilenet_v3_large.onnx

# %% [markdown]
# ## Checking omnx version

# %%
import onnx
onnx_model = onnx.load("/content/drive/MyDrive/ssdlite320_mobilenet_v3_large.onnx")
onnx.checker.check_model(onnx_model)

# %% [markdown]
# You can also visualize the omnx on https://netron.app/ by uploading the model to netron

# %% [markdown]
# ## Omnx runtime

# %%
# !pip install onnxruntime --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 15.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.1 MB/s eta 0:00:00

# %%
import onnxruntime

onnx_input = onnx_program.adapt_torch_inputs_to_onnx(torch_input)
print(f"Input length: {len(onnx_input)}")
print(f"Sample input: {onnx_input}")

ort_session = onnxruntime.InferenceSession("./my_image_classifier.onnx", providers=['CPUExecutionProvider'])

def to_numpy(tensor):
    return tensor.detach().cpu().numpy() if tensor.requires_grad else tensor.cpu().numpy()

onnxruntime_input = {k.name: to_numpy(v) for k, v in zip(ort_session.get_inputs(), onnx_input)}

onnxruntime_outputs = ort_session.run(None, onnxruntime_input)
